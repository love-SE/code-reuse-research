# %%
import pandas as pd
from datetime import datetime
import time
import os
from tqdm import tqdm
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./prj commit nums-time and code reuse ratio.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   prj               793 non-null    object
#  1   2001              793 non-null    int64
#  2   2002              793 non-null    int64
#  3   2003              793 non-null    int64
#  4   2004              793 non-null    int64
#  5   2005              793 non-null    int64
#  6   2006              793 non-null    int64
#  7   2007              793 non-null    int64
#  8   2008              793 non-null    int64
#  9   2009              793 non-null    int64
#  10  2010              793 non-null    int64
#  11  2011              793 non-null    int64
#  12  2012              793 non-null    int64
#  13  2013              793 non-null    int64
#  14  2014              793 non-null    int64
#  15  2015              793 non-null    int64
# ...

# %%
group = df.groupby('year')

# %%
info = dict()
for i in range(2001, 2021):
    temp_df = group.get_group(i)['code reuse ratio']
    temp_df = temp_df[temp_df!=0]
    info[i] = list(temp_df)

# %%
info
# Out:
# {2001: [4.2483660130719],
#  2002: [1.16279069767442],
#  2003: [0.328407224958949, 5.30421216848674],
#  2004: [3.44395742016281],
#  2005: [1.11856823266219],
#  2006: [0.253807106598985, 14.2857142857143, 1.14035087719298],
#  2007: [1.37614678899083,
#   3.10269934843314,
#   2.57699560025141,
#   4.9901185770751,
#   4.97354497354497,
#   1.31313131313131],
#  2008: [3.34832583708146,
#   2.00803212851406,
#   3.1413612565445,
#   7.89473684210526,
#   2.33463035019455,
#   6.33116883116883,
#   5.11627906976744],
#  2009: [4.02097902097902,
#   4.52674897119342,
#   2.30664857530529,
#   4.78692352597782,
#   3.34645669291339,
#   4.15129151291513,
#   5.99455040871935,
#   5.3981827899519,
#   4.21104780777805,
#   1.26463700234192],
#  2010: [4.36507936507936,
#   1.12044817927171,
#   4.45977011494253,
#   4.13793103448276,
#   4.46280991735537,
#   2.0,
#   4.88954344624448,
#   3.13971742543171,
#   3.87858347386172,
#   3.96551724137931,
#   4.87483530961792,
# ...

# %%
four_part = [[], [], [], []]
num = -1
for i, v in enumerate(list(info.values())):
    if i%5 == 0:
        num+=1
    four_part[num].extend(v)
plt.figure(dpi=200)

plt.boxplot(four_part,
            labels = ['Older','Old','New','Newer'],
            patch_artist=True,
            showmeans=True,
            boxprops = {'color':'black','facecolor':'#1E90FF'},
            showfliers = False,
            meanprops = {'marker':'o','markerfacecolor':'red'},
            medianprops = {'linestyle':'--','color':'black'},)
plt.grid()
plt.ylabel('Code Reuse Ratio (unit: %)')
plt.savefig('new old prj code reuse.jpg')
plt.show()

# %%
x = group.get_group(2019)['code reuse ratio']
x = x[x!=0]
x
# Out:
# 28     27.601810
# 83      0.998573
# 112     5.892256
# 123     8.953901
# 163    10.958904
# 207     3.551136
# 215    10.526316
# 252     4.444444
# 312     2.702703
# 323     2.439024
# 346     2.941176
# 416     8.579088
# 486     4.666667
# 491     2.550638
# 519    12.500000
# 536     6.098514
# 538     5.882353
# 625     6.451613
# Name: code reuse ratio, dtype: float64

# %%
import numpy as np
for i in range(4):
    print(len(four_part[i]))
# Out:
# 6
# 49
# 270
# 262

# %%
6+49+273+262
# Out:
# 590

# %%
info = dict()
for i in range(2001, 2021):
    temp_df = group.get_group(i)['code reuse ratio']
    # temp_df = temp_df[temp_df!=0]
    info[i] = list(temp_df)

four_part = [[], [], [], []]
num = -1
for i, v in enumerate(list(info.values())):
    if i%5 == 0:
        num+=1
    four_part[num].extend(v)

for i in range(4):
    print(len(four_part[i]))
# Out:
# 6
# 51
# 372
# 364

# %%
6+51+372+364
# Out:
# 793
